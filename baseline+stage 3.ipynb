# %%
# !pip install wfdb
# Out:
# Collecting wfdb
#   Downloading wfdb-4.3.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.13.2)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2025.10.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.7.2)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.26.4)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.2.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.32.5)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.15.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2025.10.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.10.0->wfdb) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp>=3.10.11->wfdb) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.26.4->wfdb) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.26.4->wfdb) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.26.4->wfdb) (2024.2.0)
# Downloading wfdb-4.3.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 3.8 MB/s eta 0:00:0000:01
# Installing collected packages: wfdb
# Successfully installed wfdb-4.3.0

# %%
import os
import glob
import random
import logging
from typing import List, Tuple, Optional
import time

import numpy as np
import mne
import wfdb

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter, defaultdict

import copy
from collections import OrderedDict
from scipy.special import expit
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### 1. CONFIGURATION
# ---

# %%
# Path to the root folder containing CHB-MIT patient directories (chb01, chb02, ...)
#DATA_ROOT = "./dataset/chb-mit-1.0.0"
DATA_ROOT = "/kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0"

# Optional: folder to cache preprocessed arrays (will be created if it doesn't exist)
PROCESSED_DIR = "/kaggle/working/processed_chb_mit"

# EEG bipolar channels to use (18 channels)
CHANNELS = [
    "FP1-F7", "F7-T7", "T7-P7", "P7-O1",
    "FP1-F3", "F3-C3", "C3-P3", "P3-O1",
    "FP2-F4", "F4-C4", "C4-P4", "P4-O2",
    "FP2-F8", "F8-T8", "T8-P8-1", "P8-O2",
    "FZ-CZ", "CZ-PZ",
]


# Windowing parameters
TIME_WINDOW = 8.0   # seconds per segment
TIME_STEP = 4.0     # seconds between segment starts

# Target sampling frequency after downsampling (CHB-MIT is originally 256 Hz)
TARGET_FS = 128.0

# Non-seizure sampling probability per candidate window (imbalance handling)
P_NON_SEIZURE = 0.01

# Train / test split at patient level
TRAIN_RATIO = 0.8

# Within-training set: validation split
VAL_RATIO = 0.3

# Random seeds for reproducibility
SEED = 2025

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training parameters
LEARNING_RATE = 1e-4
BATCH_SIZE = 256
EPOCHS = 200
EARLY_STOPPING_PATIENCE = 20

# %% [markdown]
# ### 2. SETUP & UTILITIES
# ---

# %%
def setup_logging():
    os.makedirs(PROCESSED_DIR, exist_ok=True)
    logging.basicConfig(
        filename=os.path.join(PROCESSED_DIR, "preprocessing.log"),
        level=logging.INFO,
        format="%(asctime)s - %(levelname)s - %(message)s"
    )
    logging.getLogger().addHandler(logging.StreamHandler())


def set_random_seeds(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # extra reproducibility settings (optional but recommended)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def list_patient_dirs(root: str) -> List[str]:
    """Return sorted list of patient directory names (e.g. ['chb01', 'chb02', ...])."""
    dirs = sorted(
        d for d in os.listdir(root)
        if os.path.isdir(os.path.join(root, d)) and d.lower().startswith("chb")
    )
    return dirs


def split_patients(patients: List[str], train_ratio: float = TRAIN_RATIO) -> Tuple[List[str], List[str]]:
    """Split patient IDs into train and test sets."""
    n_train = int(round(train_ratio * len(patients)))
    train = sorted(random.sample(patients, n_train))
    test = sorted([p for p in patients if p not in train])
    return train, test


def collect_edf_files(root: str, patient_ids: List[str]) -> List[str]:
    """Collect all .edf files for given patient IDs."""
    files = []
    for pid in patient_ids:
        pattern = os.path.join(root, pid, "*.edf")
        files.extend(sorted(glob.glob(pattern)))
    return files

def processed_files_exist(processed_dir):
    required = [
        "X_train.npy", "y_train.npy",
        "X_val.npy", "y_val.npy",
        "X_test.npy", "y_test.npy",
    ]
    return all(os.path.exists(os.path.join(processed_dir, f)) for f in required)

# %% [markdown]
# ### 3. Data Processing
# ---
# #### SEIZURE ANNOTATIONS

# %%
def load_seizure_mask(edf_path: str, n_samples: int, fs: float) -> np.ndarray:
    """
    Load seizure annotations for a given EDF file and return a binary mask
    of shape (n_samples,), where 1 indicates seizure.

    This assumes there is an annotation file with extension '.seizures'
    that WFDB can read via rdann.
    """
    mask = np.zeros(n_samples, dtype=np.int8)

    #record_base = os.path.splitext(edf_path)[0]  # includes path, without .edf
    record_base = edf_path
    ann_path = record_base + ".seizures"
    if not os.path.exists(ann_path):
        # No annotation file; treat as all non-seizure
        return mask

    try:
        # WFDB expects the "record name" without extension; can include path
        ann = wfdb.rdann(record_base, "seizures")
    except Exception as e:
        logging.warning(f"Failed to read annotation for {edf_path}: {e}")
        return mask

    # Typical assumption: ann.sample[0], ann.sample[1] are start/end of seizure 1, etc.
    samples = ann.sample
    if len(samples) < 2:
        return mask

    # Pair successive samples as start/end
    for start, end in zip(samples[0::2], samples[1::2]):
        start = max(0, int(start))
        end = min(n_samples, int(end))
        if end > start:
            mask[start:end] = 1

    return mask

# %% [markdown]
# #### PER-FILE WINDOWING

# %%
def process_file_to_windows(
    edf_path: str,
    channels: List[str],
    time_window: float,
    time_step: float,
    target_fs: float,
    p_non_seizure: float
) -> Tuple[Optional[np.ndarray], Optional[np.ndarray]]:
    """
    Read one EDF file, extract sliding windows for the specified channels,
    and return:
        segments: (N_windows_selected, n_channels, n_time_samples)
        labels:   (N_windows_selected,) bool (True = seizure)

    Returns (None, None) if channels are not all present or no windows selected.
    """
    try:
        raw = mne.io.read_raw_edf(edf_path, preload=True, verbose="ERROR")
    except Exception as e:
        logging.warning(f"Failed to read {edf_path}: {e}")
        return None, None

    # Check channel availability
    available = set(raw.ch_names)
    if not all(ch in available for ch in channels):
        logging.info(f"Skipping {edf_path}: required channels missing.")
        return None, None

    raw.pick(channels)
    fs = float(raw.info["sfreq"])
    data = raw.get_data() * 1e6  # convert to microvolts
    n_channels, n_samples = data.shape

    # Build sample-level seizure mask (based on original sampling rate)
    sz_mask = load_seizure_mask(edf_path, n_samples, fs)

    # Downsample to target_fs by simple decimation (integer factor)
    if fs != target_fs:
        factor = int(round(fs / target_fs))
        if factor <= 0:
            raise ValueError(f"Invalid downsampling factor from fs={fs} to {target_fs}")
        data = data[:, ::factor]
        sz_mask = sz_mask[::factor]
        fs = fs / factor
        n_channels, n_samples = data.shape

    # Convert seconds to samples
    win_len = int(round(time_window * fs))
    step = int(round(time_step * fs))

    if n_samples < win_len:
        return None, None

    # Number of windows
    n_windows = 1 + (n_samples - win_len) // step
    if n_windows <= 0:
        return None, None

    # Compute seizure ratio for each window and keep segments in memory
    segs = []
    ratios = []

    for i in range(n_windows):
        start = i * step
        end = start + win_len
        seg = data[:, start:end]
        # Safety check for shape
        if seg.shape[1] != win_len:
            continue
        segs.append(seg)

        win_mask = sz_mask[start:end]
        ratio = win_mask.mean() if len(win_mask) > 0 else 0.0
        ratios.append(ratio)

    segs = np.stack(segs, axis=0)  # (n_windows, n_channels, win_len)
    ratios = np.array(ratios)

    # Select seizure and a subset of non-seizure windows
    idx_pos = np.where(ratios > 0.0)[0]
    idx_neg = np.where(ratios == 0.0)[0]

    selected_indices = []

    if len(idx_pos) > 0:
        selected_indices.append(idx_pos)

    if len(idx_neg) > 0 and p_non_seizure > 0.0:
        n_neg = int(round(p_non_seizure * len(idx_neg)))
        n_neg = max(0, min(n_neg, len(idx_neg)))
        if n_neg > 0:
            chosen_neg = np.random.choice(idx_neg, size=n_neg, replace=False)
            selected_indices.append(chosen_neg)

    if not selected_indices:
        return None, None

    selected_indices = np.concatenate(selected_indices)
    np.random.shuffle(selected_indices)

    segs = segs[selected_indices]
    labels = ratios[selected_indices] > 0.0  # bool: seizure if any seizure in window

    return segs, labels

# %% [markdown]
#  #### DATASET BUILDING

# %%
def build_dataset_from_files(files: List[str]) -> Tuple[np.ndarray, np.ndarray, float]:
    """
    Build dataset (segments, labels) from a list of EDF files.

    Returns:
        X: (N_segments, n_channels, n_time_samples)
        y: (N_segments,) bool
        fs: target sampling frequency used
    """
    all_segments = []
    all_labels = []

    for idx, fpath in enumerate(files):
        logging.info(f"[{idx + 1}/{len(files)}] Processing {fpath}")
        segs, labels = process_file_to_windows(
            fpath,
            channels=CHANNELS,
            time_window=TIME_WINDOW,
            time_step=TIME_STEP,
            target_fs=TARGET_FS,
            p_non_seizure=P_NON_SEIZURE
        )
        if segs is None:
            continue

        all_segments.append(segs)
        all_labels.append(labels)

    if not all_segments:
        raise RuntimeError("No segments were extracted from the provided files.")

    X = np.concatenate(all_segments, axis=0)
    y = np.concatenate(all_labels, axis=0)

    logging.info(f"Built dataset: X.shape={X.shape}, y.shape={y.shape}, "
                 f"seizure_ratio={y.mean():.4f}")

    return X, y.astype(bool), TARGET_FS

# %% [markdown]
# # Stage 2: Baseline creation

# %% [markdown]
# ### 4. MODEL DEFINITION
# ---

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class EEGCNN(nn.Module):
    """
    2D CNN for EEG windows.

    Expects input of shape: (batch_size, 1, n_channels, n_time)
    Returns raw logits of shape: (batch_size, 1)
    """

    def __init__(self, in_channels):
        super().__init__()
        
        # 1D Convolutional Blocks
        self.conv1 = nn.Conv1d(in_channels, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(64, 64, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool1d(2)
        
        self.conv3 = nn.Conv1d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv1d(128, 128, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool1d(2)
        
        self.conv5 = nn.Conv1d(128, 256, kernel_size=3, padding=1)
        self.conv6 = nn.Conv1d(256, 256, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool1d(2)
        
        # Classification Head
        self.global_pool = nn.AdaptiveAvgPool1d(1)
        self.fc1 = nn.Linear(256, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1) # Final logic (binary)

    def forward(self, x):
        # x: (B, C, T)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.pool1(x)
        
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = self.pool2(x)
        
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = self.pool3(x)
        
        # Global Average Pooling
        x = self.global_pool(x).squeeze(-1) # (B, 256)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x) # (B, 1)
        
        return x.squeeze(1)

# %% [markdown]
# ### 5. TRAINING & EVALUATION
# ---

# %%
def train_and_evaluate(
    X_train: np.ndarray,
    y_train: np.ndarray,
    X_val: np.ndarray,
    y_val: np.ndarray,
    X_test: np.ndarray,
    y_test: np.ndarray
):
    """
    Train the CNN (PyTorch) and evaluate on validation and test sets.
    Prints Keras-style logs and records training curves.
    Assumes EEGCNN.forward returns logits of shape (B,)
    and y_* are 0/1 arrays.
    """

    # ---- prepare tensors & loaders ----
    X_train_t = torch.from_numpy(X_train).float()  # (N,C,T)
    X_val_t   = torch.from_numpy(X_val).float()
    X_test_t  = torch.from_numpy(X_test).float()

    y_train_t = torch.from_numpy(y_train.astype(np.float32))
    y_val_t   = torch.from_numpy(y_val.astype(np.float32))
    y_test_t  = torch.from_numpy(y_test.astype(np.float32))

    train_ds = TensorDataset(X_train_t, y_train_t)
    val_ds   = TensorDataset(X_val_t, y_val_t)
    test_ds  = TensorDataset(X_test_t, y_test_t)

    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
    test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

    # ---- model, loss, optimizer, scheduler ----
    model = EEGCNN(in_channels=len(CHANNELS)).to(DEVICE)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        factor=0.5,
        patience=5,
        verbose=True
    )

    best_val_loss = float("inf")
    best_state = None
    epochs_no_improve = 0

    # history containers
    train_losses, val_losses = [], []
    train_accs, val_accs = [], []
    lrs = []

    # ---- training loop ----
    for epoch in range(1, EPOCHS + 1):
        epoch_start = time.time()

        # ----- TRAIN -----
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for step, (xb, yb) in enumerate(train_loader, start=1):
            xb = xb.to(DEVICE)
            yb = yb.to(DEVICE)

            optimizer.zero_grad()
            logits = model(xb)                  # (B,)
            loss = criterion(logits, yb)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * xb.size(0)

            # accuracy
            probs = torch.sigmoid(logits)
            preds = (probs > 0.5).float()
            correct += (preds == yb).sum().item()
            total += yb.numel()

        train_loss = running_loss / total
        train_acc = correct / total

        # ----- VALIDATION -----
        model.eval()
        val_running_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for xb, yb in val_loader:
                xb = xb.to(DEVICE)
                yb = yb.to(DEVICE)

                logits = model(xb)
                loss = criterion(logits, yb)
                val_running_loss += loss.item() * xb.size(0)

                probs = torch.sigmoid(logits)
                preds = (probs > 0.5).float()
                val_correct += (preds == yb).sum().item()
                val_total += yb.numel()

        val_loss = val_running_loss / val_total
        val_acc = val_correct / val_total

        # ---- scheduler + history ----
        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]["lr"]

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        lrs.append(current_lr)

        epoch_time = time.time() - epoch_start
        steps_per_epoch = len(train_loader)
        ms_per_step = (epoch_time / steps_per_epoch) * 1000

        # Keras-style line
        print(f"{epoch}/{EPOCHS} - {epoch_time:.0f}s - {ms_per_step:.0f}ms/step "
              f"- accuracy: {train_acc:.4f} - loss: {train_loss:.4f} "
              f"- val_accuracy: {val_acc:.4f} - val_loss: {val_loss:.4f} "
              f"- lr: {current_lr:.2e}")

        # ---- early stopping ----
        if val_loss < best_val_loss - 1e-4:
            best_val_loss = val_loss
            best_state = model.state_dict()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= EARLY_STOPPING_PATIENCE:
                print(f"Early stopping at epoch {epoch}")
                break

    # restore best weights
    if best_state is not None:
        model.load_state_dict(best_state)

    # ---- evaluation helper ----
    def eval_on_loader(loader):
        model.eval()
        all_probs, all_labels = [], []
        with torch.no_grad():
            for xb, yb in loader:
                xb = xb.to(DEVICE)
                logits = model(xb)              # (B,)
                probs = torch.sigmoid(logits)   # (B,)
                all_probs.append(probs.cpu().numpy())
                all_labels.append(yb.cpu().numpy())
        all_probs = np.concatenate(all_probs)
        all_labels = np.concatenate(all_labels)
        preds = (all_probs > 0.5).astype(int)
        return all_labels, all_probs, preds

    # ---- validation metrics ----
    y_val_true, y_val_probs, y_val_pred = eval_on_loader(val_loader)
    print("=== Validation report (threshold=0.5) ===")
    print(classification_report(y_val_true, y_val_pred, digits=4))
    try:
        val_auc = roc_auc_score(y_val_true, y_val_probs)
        print(f"Validation ROC AUC: {val_auc:.4f}")
    except ValueError:
        print("Validation ROC AUC: not defined (only one class present).")

    # ---- test metrics ----
    y_test_true, y_test_probs, y_test_pred = eval_on_loader(test_loader)
    print("=== Test report (threshold=0.5) ===")
    print(classification_report(y_test_true, y_test_pred, digits=4))
    try:
        test_auc = roc_auc_score(y_test_true, y_test_probs)
        print(f"Test ROC AUC: {test_auc:.4f}")
    except ValueError:
        print("Test ROC AUC: not defined (only one class present).")

    # ---- PLOTS: training curves ----
    epochs_range = range(1, len(train_losses) + 1)

    # Loss curves
    plt.figure(figsize=(6, 4))
    plt.plot(epochs_range, train_losses, label="Train loss")
    plt.plot(epochs_range, val_losses, label="Val loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training / validation loss")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Accuracy curves (optional but useful)
    plt.figure(figsize=(6, 4))
    plt.plot(epochs_range, train_accs, label="Train accuracy")
    plt.plot(epochs_range, val_accs, label="Val accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("Training / validation accuracy")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # LR curve
    plt.figure(figsize=(6, 4))
    plt.plot(epochs_range, lrs)
    plt.xlabel("Epoch")
    plt.ylabel("Learning rate")
    plt.title("Learning rate schedule")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    history = {
        "train_loss": train_losses,
        "val_loss": val_losses,
        "train_acc": train_accs,
        "val_acc": val_accs,
        "lr": lrs,
    }

    return model, history

# %% [markdown]
#  ### 6. MAIN PIPELINE
#  ---

# %%
# 0. config
setup_logging()
set_random_seeds(SEED)

# %%
# 1. Build train & test datasets
if processed_files_exist(PROCESSED_DIR):
    print("📂 Loading cached preprocessed dataset...")

    X_train = np.load(os.path.join(PROCESSED_DIR, "X_train.npy"))
    y_train = np.load(os.path.join(PROCESSED_DIR, "y_train.npy"))
    X_val   = np.load(os.path.join(PROCESSED_DIR, "X_val.npy"))
    y_val   = np.load(os.path.join(PROCESSED_DIR, "y_val.npy"))
    X_test  = np.load(os.path.join(PROCESSED_DIR, "X_test.npy"))
    y_test  = np.load(os.path.join(PROCESSED_DIR, "y_test.npy"))
else:
    # 1) Get all patients and all EDF files
    patients = list_patient_dirs(DATA_ROOT)
    if not patients:
        raise RuntimeError(f"No patient directories found under {DATA_ROOT}")

    # Collect ALL EDF files from ALL patients
    all_files = collect_edf_files(DATA_ROOT, patients)
    print(f"Total EDF files: {len(all_files)}")

    # 2) Build one big dataset (all patients concatenated)
    print("Building full dataset from all patients...")
    X_all, y_all, fs_all = build_dataset_from_files(all_files)

    assert fs_all == TARGET_FS
    print(f"Full dataset: X_all = {X_all.shape}, y_all = {y_all.shape}")

    # 3) Split into train / val / test on the SEGMENT level
    #    Keep global proportions consistent with your old TRAIN_RATIO/VAL_RATIO:
    #    - First: TRAIN vs TEST using TRAIN_RATIO
    #    - Then: split TRAIN part into (train, val) with VAL_RATIO
    TEST_RATIO = 1.0 - TRAIN_RATIO

    # 3a) Train+Val vs Test
    X_temp, X_test, y_temp, y_test = train_test_split(
        X_all,
        y_all,
        test_size=TEST_RATIO,
        stratify=y_all,
        random_state=SEED,
    )

    # 3b) Train vs Val (inside the previous TRAIN part)
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp,
        y_temp,
        test_size=VAL_RATIO,
        stratify=y_temp,
        random_state=SEED,
    )

    print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"X_val:   {X_val.shape}, y_val:   {y_val.shape}")
    print(f"X_test:  {X_test.shape}, y_test:  {y_test.shape}")

    # 4) Save splits
    np.save(os.path.join(PROCESSED_DIR, "X_train.npy"), X_train)
    np.save(os.path.join(PROCESSED_DIR, "y_train.npy"), y_train)
    np.save(os.path.join(PROCESSED_DIR, "X_val.npy"), X_val)
    np.save(os.path.join(PROCESSED_DIR, "y_val.npy"), y_val)
    np.save(os.path.join(PROCESSED_DIR, "X_test.npy"), X_test)
    np.save(os.path.join(PROCESSED_DIR, "y_test.npy"), y_test)
    print(f"Datasets saved under: {PROCESSED_DIR}")

    print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"X_val:   {X_val.shape}, y_val:   {y_val.shape}")
    print(f"X_test:  {X_test.shape}, y_test:  {y_test.shape}")
# Out:
# [1/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_01.edf
# Total EDF files: 686
# Building full dataset from all patients...
# [2/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_02.edf
# [3/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_03.edf
# [4/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_04.edf
# [5/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_05.edf
# [6/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_06.edf
# [7/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_07.edf
# [8/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_08.edf
# [9/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_09.edf
# [10/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_10.edf
# [11/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_11.edf
# [12/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_12.edf
# [13/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_13.edf
# [14/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_14.edf
# [15/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_15.edf
# [16/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_16.edf
# [17/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_17.edf
# [18/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_18.edf
# [19/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_19.edf
# [20/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_20.edf
# [21/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_21.edf
# [22/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_22.edf
# [23/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_23.edf
# [24/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_24.edf
# [25/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_25.edf
# [26/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_26.edf
# [27/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_27.edf
# [28/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_29.edf
# [29/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_30.edf
# [30/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_31.edf
# [31/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_32.edf
# [32/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_33.edf
# [33/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_34.edf
# [34/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_36.edf
# [35/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_37.edf
# [36/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_38.edf
# [37/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_39.edf
# [38/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_40.edf
# [39/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_41.edf
# [40/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_42.edf
# [41/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_43.edf
# [42/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb01/chb01_46.edf
# [43/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_01.edf
# [44/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_02.edf
# [45/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_03.edf
# [46/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_04.edf
# [47/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_05.edf
# [48/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_06.edf
# [49/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_07.edf
# [50/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_08.edf
# [51/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_09.edf
# [52/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_10.edf
# [53/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_11.edf
# [54/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_12.edf
# [55/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_13.edf
# [56/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_14.edf
# [57/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_15.edf
# [58/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_16+.edf
# [59/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_16.edf
# [60/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_17.edf
# [61/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_18.edf
# [62/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_19.edf
# [63/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_20.edf
# [64/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_21.edf
# [65/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_22.edf
# [66/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_23.edf
# [67/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_24.edf
# [68/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_25.edf
# [69/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_26.edf
# [70/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_27.edf
# [71/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_28.edf
# [72/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_29.edf
# [73/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_30.edf
# [74/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_31.edf
# [75/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_32.edf
# [76/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_33.edf
# [77/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_34.edf
# [78/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_35.edf
# [79/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_01.edf
# [80/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_02.edf
# [81/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_03.edf
# [82/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_04.edf
# [83/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_05.edf
# [84/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_06.edf
# [85/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_07.edf
# [86/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_08.edf
# [87/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_09.edf
# [88/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_10.edf
# [89/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_11.edf
# [90/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_12.edf
# [91/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_13.edf
# [92/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_14.edf
# [93/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_15.edf
# [94/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_16.edf
# [95/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_17.edf
# [96/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_18.edf
# [97/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_19.edf
# [98/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_20.edf
# [99/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_21.edf
# [100/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_22.edf
# [101/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_23.edf
# [102/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_24.edf
# [103/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_25.edf
# [104/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_26.edf
# [105/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_27.edf
# [106/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_28.edf
# [107/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_29.edf
# [108/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_30.edf
# [109/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_31.edf
# [110/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_32.edf
# [111/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_33.edf
# [112/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_34.edf
# [113/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_35.edf
# [114/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_36.edf
# [115/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_37.edf
# [116/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_38.edf
# [117/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_01.edf
# [118/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_02.edf
# [119/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_03.edf
# [120/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_04.edf
# [121/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_05.edf
# [122/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_06.edf
# [123/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_07.edf
# [124/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_08.edf
# [125/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_09.edf
# [126/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_10.edf
# [127/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_11.edf
# [128/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_12.edf
# [129/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_13.edf
# [130/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_14.edf
# [131/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_15.edf
# [132/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_16.edf
# [133/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_17.edf
# [134/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_18.edf
# [135/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_19.edf
# [136/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_21.edf
# [137/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_22.edf
# [138/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_23.edf
# [139/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_24.edf
# [140/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_25.edf
# [141/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_26.edf
# [142/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_27.edf
# [143/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_28.edf
# [144/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_29.edf
# [145/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_30.edf
# [146/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_31.edf
# [147/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_32.edf
# [148/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_33.edf
# [149/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_34.edf
# [150/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_35.edf
# [151/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_36.edf
# [152/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_37.edf
# [153/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_38.edf
# [154/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_39.edf
# [155/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_40.edf
# [156/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_41.edf
# [157/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_42.edf
# [158/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_43.edf
# [159/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_01.edf
# [160/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_02.edf
# [161/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_03.edf
# [162/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_04.edf
# [163/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_05.edf
# [164/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_06.edf
# [165/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_07.edf
# [166/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_08.edf
# [167/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_09.edf
# [168/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_10.edf
# [169/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_11.edf
# [170/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_12.edf
# [171/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_13.edf
# [172/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_14.edf
# [173/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_15.edf
# [174/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_16.edf
# [175/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_17.edf
# [176/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_18.edf
# [177/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_19.edf
# [178/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_20.edf
# [179/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_21.edf
# [180/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_22.edf
# [181/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_23.edf
# [182/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_24.edf
# [183/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_25.edf
# [184/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_26.edf
# [185/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_27.edf
# [186/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_28.edf
# [187/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_29.edf
# [188/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_30.edf
# [189/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_31.edf
# [190/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_32.edf
# [191/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_33.edf
# [192/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_34.edf
# [193/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_35.edf
# [194/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_36.edf
# [195/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_37.edf
# [196/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_38.edf
# [197/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_39.edf
# [198/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_01.edf
# [199/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_02.edf
# [200/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_03.edf
# [201/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_04.edf
# [202/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_05.edf
# [203/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_06.edf
# [204/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_07.edf
# [205/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_08.edf
# [206/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_09.edf
# [207/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_10.edf
# [208/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_12.edf
# [209/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_13.edf
# [210/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_14.edf
# [211/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_15.edf
# [212/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_16.edf
# [213/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_17.edf
# [214/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_18.edf
# [215/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_24.edf
# [216/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_01.edf
# [217/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_02.edf
# [218/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_03.edf
# [219/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_04.edf
# [220/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_05.edf
# [221/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_06.edf
# [222/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_07.edf
# [223/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_08.edf
# [224/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_09.edf
# [225/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_10.edf
# [226/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_11.edf
# [227/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_12.edf
# [228/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_13.edf
# [229/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_14.edf
# [230/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_15.edf
# [231/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_16.edf
# [232/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_17.edf
# [233/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_18.edf
# [234/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb07/chb07_19.edf
# [235/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_02.edf
# [236/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_03.edf
# [237/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_04.edf
# [238/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_05.edf
# [239/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_10.edf
# [240/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_11.edf
# [241/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_12.edf
# [242/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_13.edf
# [243/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_14.edf
# [244/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_15.edf
# [245/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_16.edf
# [246/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_17.edf
# [247/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_18.edf
# [248/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_19.edf
# [249/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_20.edf
# [250/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_21.edf
# [251/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_22.edf
# [252/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_23.edf
# [253/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_24.edf
# [254/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb08/chb08_29.edf
# [255/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_01.edf
# [256/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_02.edf
# [257/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_03.edf
# [258/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_04.edf
# [259/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_05.edf
# [260/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_06.edf
# [261/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_07.edf
# [262/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_08.edf
# [263/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_09.edf
# [264/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_10.edf
# [265/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_11.edf
# [266/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_12.edf
# [267/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_13.edf
# [268/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_14.edf
# [269/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_15.edf
# [270/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_16.edf
# [271/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_17.edf
# [272/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_18.edf
# [273/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb09/chb09_19.edf
# [274/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_01.edf
# [275/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_02.edf
# [276/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_03.edf
# [277/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_04.edf
# [278/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_05.edf
# [279/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_06.edf
# [280/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_07.edf
# [281/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_08.edf
# [282/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_12.edf
# [283/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_13.edf
# [284/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_14.edf
# [285/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_15.edf
# [286/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_16.edf
# [287/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_17.edf
# [288/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_18.edf
# [289/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_19.edf
# [290/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_20.edf
# [291/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_21.edf
# [292/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_22.edf
# [293/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_27.edf
# [294/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_28.edf
# [295/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_30.edf
# [296/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_31.edf
# [297/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_38.edf
# [298/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb10/chb10_89.edf
# [299/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_01.edf
# [300/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_02.edf
# [301/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_03.edf
# [302/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_04.edf
# [303/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_05.edf
# [304/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_06.edf
# [305/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_07.edf
# [306/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_08.edf
# [307/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_09.edf
# [308/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_10.edf
# [309/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_11.edf
# [310/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_12.edf
# [311/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_13.edf
# [312/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_14.edf
# [313/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_15.edf
# [314/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb11/chb11_16.edf
# ...
# [586/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb20/chb20_30.edf
# [587/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb20/chb20_31.edf
# [588/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb20/chb20_34.edf
# [589/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb20/chb20_59.edf
# [590/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb20/chb20_60.edf
# [591/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb20/chb20_68.edf
# [592/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_01.edf
# [593/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_02.edf
# [594/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_03.edf
# [595/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_04.edf
# [596/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_05.edf
# [597/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_06.edf
# [598/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_07.edf
# [599/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_08.edf
# [600/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_09.edf
# [601/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_10.edf
# [602/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_11.edf
# [603/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_12.edf
# [604/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_13.edf
# [605/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_14.edf
# [606/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_15.edf
# [607/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_16.edf
# [608/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_17.edf
# [609/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_18.edf
# [610/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_19.edf
# [611/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_20.edf
# [612/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_21.edf
# [613/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_22.edf
# [614/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_23.edf
# [615/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_24.edf
# [616/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_25.edf
# [617/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_26.edf
# [618/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_27.edf
# [619/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_28.edf
# [620/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_29.edf
# [621/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_30.edf
# [622/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_31.edf
# [623/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_32.edf
# [624/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb21/chb21_33.edf
# [625/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_01.edf
# [626/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_02.edf
# [627/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_03.edf
# [628/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_04.edf
# [629/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_05.edf
# [630/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_06.edf
# [631/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_07.edf
# [632/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_08.edf
# [633/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_09.edf
# [634/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_10.edf
# [635/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_11.edf
# [636/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_15.edf
# [637/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_16.edf
# [638/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_17.edf
# [639/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_18.edf
# [640/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_19.edf
# [641/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_20.edf
# [642/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_21.edf
# [643/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_22.edf
# [644/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_23.edf
# [645/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_24.edf
# [646/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_25.edf
# [647/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_26.edf
# [648/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_27.edf
# [649/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_28.edf
# [650/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_29.edf
# [651/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_30.edf
# [652/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_38.edf
# [653/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_51.edf
# [654/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_54.edf
# [655/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb22/chb22_77.edf
# [656/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb23/chb23_06.edf
# [657/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb23/chb23_07.edf
# [658/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb23/chb23_08.edf
# [659/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb23/chb23_09.edf
# [660/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb23/chb23_10.edf
# [661/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb23/chb23_16.edf
# [662/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb23/chb23_17.edf
# [663/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb23/chb23_19.edf
# [664/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb23/chb23_20.edf
# [665/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_01.edf
# [666/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_02.edf
# [667/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_03.edf
# [668/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_04.edf
# [669/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_05.edf
# [670/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_06.edf
# [671/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_07.edf
# [672/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_08.edf
# [673/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_09.edf
# [674/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_10.edf
# [675/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_11.edf
# [676/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_12.edf
# [677/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_13.edf
# [678/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_14.edf
# [679/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_15.edf
# [680/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_16.edf
# [681/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_17.edf
# [682/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_18.edf
# [683/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_19.edf
# [684/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_20.edf
# [685/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_21.edf
# [686/686] Processing /kaggle/input/d/abhishekinnvonix/seizure-epilepcy-chb-mit-eeg-dataset-pediatric/chb-mit-scalp-eeg-database-1.0.0/chb24/chb24_22.edf
# Built dataset: X.shape=(11725, 18, 1024), y.shape=(11725,), seizure_ratio=0.2709
# Full dataset: X_all = (11725, 18, 1024), y_all = (11725,)
# X_train: (6566, 18, 1024), y_train: (6566,)
# X_val:   (2814, 18, 1024), y_val:   (2814,)
# X_test:  (2345, 18, 1024), y_test:  (2345,)
# Datasets saved under: /kaggle/working/processed_chb_mit
# X_train: (6566, 18, 1024), y_train: (6566,)
# X_val:   (2814, 18, 1024), y_val:   (2814,)
# X_test:  (2345, 18, 1024), y_test:  (2345,)

# %%
# 2. Train and evaluate model
model, history = train_and_evaluate(X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 1/200 - 4s - 169ms/step - accuracy: 0.5603 - loss: 0.6970 - val_accuracy: 0.7274 - val_loss: 0.6806 - lr: 1.00e-04
# 2/200 - 2s - 95ms/step - accuracy: 0.7403 - loss: 0.6671 - val_accuracy: 0.7615 - val_loss: 0.6357 - lr: 1.00e-04
# 3/200 - 2s - 95ms/step - accuracy: 0.7702 - loss: 0.5932 - val_accuracy: 0.7996 - val_loss: 0.5431 - lr: 1.00e-04
# 4/200 - 3s - 97ms/step - accuracy: 0.7981 - loss: 0.5239 - val_accuracy: 0.8053 - val_loss: 0.5042 - lr: 1.00e-04
# 5/200 - 2s - 96ms/step - accuracy: 0.8101 - loss: 0.4911 - val_accuracy: 0.8216 - val_loss: 0.4689 - lr: 1.00e-04
# 6/200 - 3s - 97ms/step - accuracy: 0.8303 - loss: 0.4474 - val_accuracy: 0.8475 - val_loss: 0.4379 - lr: 1.00e-04
# 7/200 - 3s - 97ms/step - accuracy: 0.8448 - loss: 0.4098 - val_accuracy: 0.8550 - val_loss: 0.3994 - lr: 1.00e-04
# 8/200 - 3s - 97ms/step - accuracy: 0.8477 - loss: 0.3962 - val_accuracy: 0.8561 - val_loss: 0.3798 - lr: 1.00e-04
# 9/200 - 3s - 97ms/step - accuracy: 0.8433 - loss: 0.3933 - val_accuracy: 0.8625 - val_loss: 0.3649 - lr: 1.00e-04
# 10/200 - 3s - 97ms/step - accuracy: 0.8638 - loss: 0.3543 - val_accuracy: 0.8664 - val_loss: 0.3519 - lr: 1.00e-04
# 11/200 - 3s - 98ms/step - accuracy: 0.8721 - loss: 0.3292 - val_accuracy: 0.8483 - val_loss: 0.3896 - lr: 1.00e-04
# 12/200 - 3s - 99ms/step - accuracy: 0.8602 - loss: 0.3487 - val_accuracy: 0.8706 - val_loss: 0.3334 - lr: 1.00e-04
# 13/200 - 3s - 105ms/step - accuracy: 0.8651 - loss: 0.3386 - val_accuracy: 0.8639 - val_loss: 0.3516 - lr: 1.00e-04
# 14/200 - 3s - 98ms/step - accuracy: 0.8645 - loss: 0.3278 - val_accuracy: 0.8785 - val_loss: 0.3172 - lr: 1.00e-04
# 15/200 - 3s - 100ms/step - accuracy: 0.8772 - loss: 0.3020 - val_accuracy: 0.8799 - val_loss: 0.3097 - lr: 1.00e-04
# 16/200 - 3s - 100ms/step - accuracy: 0.8821 - loss: 0.2924 - val_accuracy: 0.8657 - val_loss: 0.3612 - lr: 1.00e-04
# 17/200 - 3s - 99ms/step - accuracy: 0.8744 - loss: 0.3155 - val_accuracy: 0.8827 - val_loss: 0.2995 - lr: 1.00e-04
# 18/200 - 3s - 100ms/step - accuracy: 0.8887 - loss: 0.2779 - val_accuracy: 0.8866 - val_loss: 0.3018 - lr: 1.00e-04
# 19/200 - 3s - 100ms/step - accuracy: 0.8922 - loss: 0.2710 - val_accuracy: 0.8877 - val_loss: 0.2991 - lr: 1.00e-04
# 20/200 - 3s - 100ms/step - accuracy: 0.8815 - loss: 0.2914 - val_accuracy: 0.8696 - val_loss: 0.3345 - lr: 1.00e-04
# 21/200 - 3s - 101ms/step - accuracy: 0.8955 - loss: 0.2687 - val_accuracy: 0.8962 - val_loss: 0.2774 - lr: 1.00e-04
# 22/200 - 3s - 101ms/step - accuracy: 0.9054 - loss: 0.2469 - val_accuracy: 0.8969 - val_loss: 0.2758 - lr: 1.00e-04
# 23/200 - 3s - 103ms/step - accuracy: 0.9047 - loss: 0.2529 - val_accuracy: 0.9065 - val_loss: 0.2680 - lr: 1.00e-04
# 24/200 - 3s - 102ms/step - accuracy: 0.9120 - loss: 0.2351 - val_accuracy: 0.9104 - val_loss: 0.2593 - lr: 1.00e-04
# 25/200 - 3s - 102ms/step - accuracy: 0.9149 - loss: 0.2271 - val_accuracy: 0.9126 - val_loss: 0.2540 - lr: 1.00e-04
# 26/200 - 3s - 103ms/step - accuracy: 0.9173 - loss: 0.2300 - val_accuracy: 0.9133 - val_loss: 0.2570 - lr: 1.00e-04
# 27/200 - 3s - 103ms/step - accuracy: 0.9197 - loss: 0.2183 - val_accuracy: 0.9151 - val_loss: 0.2485 - lr: 1.00e-04
# 28/200 - 3s - 103ms/step - accuracy: 0.9197 - loss: 0.2135 - val_accuracy: 0.9090 - val_loss: 0.2634 - lr: 1.00e-04
# 29/200 - 3s - 104ms/step - accuracy: 0.9187 - loss: 0.2225 - val_accuracy: 0.9151 - val_loss: 0.2483 - lr: 1.00e-04
# 30/200 - 3s - 105ms/step - accuracy: 0.9223 - loss: 0.2086 - val_accuracy: 0.9140 - val_loss: 0.2561 - lr: 1.00e-04
# 31/200 - 3s - 105ms/step - accuracy: 0.9185 - loss: 0.2161 - val_accuracy: 0.9154 - val_loss: 0.2462 - lr: 1.00e-04
# 32/200 - 3s - 105ms/step - accuracy: 0.9302 - loss: 0.1931 - val_accuracy: 0.9104 - val_loss: 0.2632 - lr: 1.00e-04
# 33/200 - 3s - 105ms/step - accuracy: 0.9267 - loss: 0.1952 - val_accuracy: 0.9222 - val_loss: 0.2248 - lr: 1.00e-04
# 34/200 - 3s - 106ms/step - accuracy: 0.9222 - loss: 0.2153 - val_accuracy: 0.8909 - val_loss: 0.3368 - lr: 1.00e-04
# 35/200 - 3s - 106ms/step - accuracy: 0.9254 - loss: 0.2106 - val_accuracy: 0.9176 - val_loss: 0.2429 - lr: 1.00e-04
# 36/200 - 3s - 108ms/step - accuracy: 0.9350 - loss: 0.1852 - val_accuracy: 0.9271 - val_loss: 0.2199 - lr: 1.00e-04
# 37/200 - 3s - 107ms/step - accuracy: 0.9277 - loss: 0.1954 - val_accuracy: 0.9275 - val_loss: 0.2226 - lr: 1.00e-04
# 38/200 - 3s - 108ms/step - accuracy: 0.9223 - loss: 0.2088 - val_accuracy: 0.9268 - val_loss: 0.2179 - lr: 1.00e-04
# 39/200 - 3s - 108ms/step - accuracy: 0.9382 - loss: 0.1754 - val_accuracy: 0.9271 - val_loss: 0.2149 - lr: 1.00e-04
# 40/200 - 3s - 109ms/step - accuracy: 0.9376 - loss: 0.1718 - val_accuracy: 0.9200 - val_loss: 0.2241 - lr: 1.00e-04
# 41/200 - 3s - 109ms/step - accuracy: 0.9251 - loss: 0.1989 - val_accuracy: 0.9179 - val_loss: 0.2511 - lr: 1.00e-04
# 42/200 - 3s - 110ms/step - accuracy: 0.9382 - loss: 0.1749 - val_accuracy: 0.9303 - val_loss: 0.2106 - lr: 1.00e-04
# 43/200 - 3s - 109ms/step - accuracy: 0.9398 - loss: 0.1685 - val_accuracy: 0.9293 - val_loss: 0.2076 - lr: 1.00e-04
# 44/200 - 3s - 109ms/step - accuracy: 0.9423 - loss: 0.1667 - val_accuracy: 0.9279 - val_loss: 0.2180 - lr: 1.00e-04
# 45/200 - 3s - 109ms/step - accuracy: 0.9408 - loss: 0.1630 - val_accuracy: 0.9332 - val_loss: 0.2082 - lr: 1.00e-04
# 46/200 - 3s - 109ms/step - accuracy: 0.9427 - loss: 0.1571 - val_accuracy: 0.9296 - val_loss: 0.2039 - lr: 1.00e-04
# 47/200 - 3s - 108ms/step - accuracy: 0.9344 - loss: 0.1771 - val_accuracy: 0.9271 - val_loss: 0.2176 - lr: 1.00e-04
# 48/200 - 3s - 108ms/step - accuracy: 0.9452 - loss: 0.1554 - val_accuracy: 0.9314 - val_loss: 0.2061 - lr: 1.00e-04
# 49/200 - 3s - 107ms/step - accuracy: 0.9382 - loss: 0.1677 - val_accuracy: 0.9200 - val_loss: 0.2470 - lr: 1.00e-04
# 50/200 - 3s - 107ms/step - accuracy: 0.9426 - loss: 0.1655 - val_accuracy: 0.9300 - val_loss: 0.2114 - lr: 1.00e-04
# 51/200 - 3s - 106ms/step - accuracy: 0.9429 - loss: 0.1547 - val_accuracy: 0.9222 - val_loss: 0.2322 - lr: 1.00e-04
# 52/200 - 3s - 107ms/step - accuracy: 0.9458 - loss: 0.1508 - val_accuracy: 0.9350 - val_loss: 0.1948 - lr: 1.00e-04
# 53/200 - 3s - 106ms/step - accuracy: 0.9487 - loss: 0.1433 - val_accuracy: 0.9275 - val_loss: 0.2196 - lr: 1.00e-04
# 54/200 - 3s - 106ms/step - accuracy: 0.9499 - loss: 0.1394 - val_accuracy: 0.9303 - val_loss: 0.2078 - lr: 1.00e-04
# 55/200 - 3s - 106ms/step - accuracy: 0.9496 - loss: 0.1401 - val_accuracy: 0.9353 - val_loss: 0.1988 - lr: 1.00e-04
# 56/200 - 3s - 106ms/step - accuracy: 0.9517 - loss: 0.1405 - val_accuracy: 0.9204 - val_loss: 0.2444 - lr: 1.00e-04
# 57/200 - 3s - 106ms/step - accuracy: 0.9502 - loss: 0.1431 - val_accuracy: 0.9339 - val_loss: 0.1990 - lr: 1.00e-04
# 58/200 - 3s - 106ms/step - accuracy: 0.9494 - loss: 0.1382 - val_accuracy: 0.9321 - val_loss: 0.2136 - lr: 5.00e-05
# 59/200 - 3s - 106ms/step - accuracy: 0.9564 - loss: 0.1260 - val_accuracy: 0.9375 - val_loss: 0.1861 - lr: 5.00e-05
# 60/200 - 3s - 106ms/step - accuracy: 0.9561 - loss: 0.1231 - val_accuracy: 0.9403 - val_loss: 0.1868 - lr: 5.00e-05
# 61/200 - 3s - 106ms/step - accuracy: 0.9590 - loss: 0.1207 - val_accuracy: 0.9367 - val_loss: 0.1905 - lr: 5.00e-05
# 62/200 - 3s - 106ms/step - accuracy: 0.9528 - loss: 0.1343 - val_accuracy: 0.9399 - val_loss: 0.1838 - lr: 5.00e-05
# 63/200 - 3s - 106ms/step - accuracy: 0.9589 - loss: 0.1193 - val_accuracy: 0.9371 - val_loss: 0.1905 - lr: 5.00e-05
# 64/200 - 3s - 106ms/step - accuracy: 0.9578 - loss: 0.1194 - val_accuracy: 0.9357 - val_loss: 0.2026 - lr: 5.00e-05
# 65/200 - 3s - 106ms/step - accuracy: 0.9528 - loss: 0.1322 - val_accuracy: 0.9399 - val_loss: 0.1869 - lr: 5.00e-05
# 66/200 - 3s - 108ms/step - accuracy: 0.9581 - loss: 0.1215 - val_accuracy: 0.9396 - val_loss: 0.1825 - lr: 5.00e-05
# 67/200 - 3s - 106ms/step - accuracy: 0.9601 - loss: 0.1180 - val_accuracy: 0.9407 - val_loss: 0.1805 - lr: 5.00e-05
# 68/200 - 3s - 114ms/step - accuracy: 0.9619 - loss: 0.1126 - val_accuracy: 0.9407 - val_loss: 0.1801 - lr: 5.00e-05
# 69/200 - 3s - 107ms/step - accuracy: 0.9598 - loss: 0.1127 - val_accuracy: 0.9375 - val_loss: 0.1859 - lr: 5.00e-05
# 70/200 - 3s - 107ms/step - accuracy: 0.9589 - loss: 0.1169 - val_accuracy: 0.9399 - val_loss: 0.1793 - lr: 5.00e-05
# 71/200 - 3s - 107ms/step - accuracy: 0.9619 - loss: 0.1101 - val_accuracy: 0.9407 - val_loss: 0.1839 - lr: 5.00e-05
# 72/200 - 3s - 107ms/step - accuracy: 0.9634 - loss: 0.1092 - val_accuracy: 0.9407 - val_loss: 0.1796 - lr: 5.00e-05
# 73/200 - 3s - 107ms/step - accuracy: 0.9625 - loss: 0.1090 - val_accuracy: 0.9414 - val_loss: 0.1816 - lr: 5.00e-05
# 74/200 - 3s - 107ms/step - accuracy: 0.9613 - loss: 0.1114 - val_accuracy: 0.9375 - val_loss: 0.2013 - lr: 5.00e-05
# 75/200 - 3s - 107ms/step - accuracy: 0.9592 - loss: 0.1165 - val_accuracy: 0.9364 - val_loss: 0.2021 - lr: 5.00e-05
# 76/200 - 3s - 107ms/step - accuracy: 0.9507 - loss: 0.1303 - val_accuracy: 0.9439 - val_loss: 0.1764 - lr: 5.00e-05
# 77/200 - 3s - 107ms/step - accuracy: 0.9616 - loss: 0.1113 - val_accuracy: 0.9424 - val_loss: 0.1756 - lr: 5.00e-05
# 78/200 - 3s - 107ms/step - accuracy: 0.9639 - loss: 0.1060 - val_accuracy: 0.9364 - val_loss: 0.2004 - lr: 5.00e-05
# 79/200 - 3s - 107ms/step - accuracy: 0.9580 - loss: 0.1146 - val_accuracy: 0.9382 - val_loss: 0.1960 - lr: 5.00e-05
# 80/200 - 3s - 107ms/step - accuracy: 0.9645 - loss: 0.1027 - val_accuracy: 0.9414 - val_loss: 0.1859 - lr: 5.00e-05
# 81/200 - 3s - 106ms/step - accuracy: 0.9641 - loss: 0.1051 - val_accuracy: 0.9385 - val_loss: 0.1944 - lr: 5.00e-05
# 82/200 - 3s - 107ms/step - accuracy: 0.9645 - loss: 0.1059 - val_accuracy: 0.9421 - val_loss: 0.1737 - lr: 5.00e-05
# 83/200 - 3s - 107ms/step - accuracy: 0.9601 - loss: 0.1080 - val_accuracy: 0.9410 - val_loss: 0.1890 - lr: 5.00e-05
# 84/200 - 3s - 108ms/step - accuracy: 0.9592 - loss: 0.1162 - val_accuracy: 0.9314 - val_loss: 0.2204 - lr: 5.00e-05
# 85/200 - 3s - 106ms/step - accuracy: 0.9651 - loss: 0.1009 - val_accuracy: 0.9446 - val_loss: 0.1711 - lr: 5.00e-05
# 86/200 - 3s - 107ms/step - accuracy: 0.9685 - loss: 0.0965 - val_accuracy: 0.9439 - val_loss: 0.1767 - lr: 5.00e-05
# 87/200 - 3s - 107ms/step - accuracy: 0.9676 - loss: 0.0973 - val_accuracy: 0.9407 - val_loss: 0.1742 - lr: 5.00e-05
# 88/200 - 3s - 107ms/step - accuracy: 0.9695 - loss: 0.0946 - val_accuracy: 0.9446 - val_loss: 0.1742 - lr: 5.00e-05
# 89/200 - 3s - 107ms/step - accuracy: 0.9714 - loss: 0.0932 - val_accuracy: 0.9431 - val_loss: 0.1728 - lr: 5.00e-05
# 90/200 - 3s - 107ms/step - accuracy: 0.9680 - loss: 0.0936 - val_accuracy: 0.9431 - val_loss: 0.1779 - lr: 5.00e-05
# 91/200 - 3s - 106ms/step - accuracy: 0.9683 - loss: 0.0967 - val_accuracy: 0.9407 - val_loss: 0.1925 - lr: 2.50e-05
# 92/200 - 3s - 106ms/step - accuracy: 0.9703 - loss: 0.0918 - val_accuracy: 0.9467 - val_loss: 0.1726 - lr: 2.50e-05
# 93/200 - 3s - 107ms/step - accuracy: 0.9732 - loss: 0.0889 - val_accuracy: 0.9428 - val_loss: 0.1729 - lr: 2.50e-05
# 94/200 - 3s - 106ms/step - accuracy: 0.9721 - loss: 0.0884 - val_accuracy: 0.9471 - val_loss: 0.1721 - lr: 2.50e-05
# 95/200 - 3s - 106ms/step - accuracy: 0.9723 - loss: 0.0884 - val_accuracy: 0.9449 - val_loss: 0.1731 - lr: 2.50e-05
# 96/200 - 3s - 107ms/step - accuracy: 0.9717 - loss: 0.0904 - val_accuracy: 0.9446 - val_loss: 0.1718 - lr: 2.50e-05
# 97/200 - 3s - 106ms/step - accuracy: 0.9737 - loss: 0.0865 - val_accuracy: 0.9424 - val_loss: 0.1867 - lr: 1.25e-05
# 98/200 - 3s - 107ms/step - accuracy: 0.9697 - loss: 0.0891 - val_accuracy: 0.9467 - val_loss: 0.1715 - lr: 1.25e-05
# 99/200 - 3s - 107ms/step - accuracy: 0.9740 - loss: 0.0846 - val_accuracy: 0.9471 - val_loss: 0.1729 - lr: 1.25e-05
# 100/200 - 3s - 107ms/step - accuracy: 0.9737 - loss: 0.0846 - val_accuracy: 0.9471 - val_loss: 0.1716 - lr: 1.25e-05
# 101/200 - 3s - 106ms/step - accuracy: 0.9744 - loss: 0.0847 - val_accuracy: 0.9463 - val_loss: 0.1753 - lr: 1.25e-05
# 102/200 - 3s - 108ms/step - accuracy: 0.9740 - loss: 0.0854 - val_accuracy: 0.9435 - val_loss: 0.1743 - lr: 1.25e-05
# 103/200 - 3s - 107ms/step - accuracy: 0.9737 - loss: 0.0845 - val_accuracy: 0.9446 - val_loss: 0.1724 - lr: 6.25e-06
# 104/200 - 3s - 106ms/step - accuracy: 0.9747 - loss: 0.0844 - val_accuracy: 0.9471 - val_loss: 0.1715 - lr: 6.25e-06
# 105/200 - 3s - 107ms/step - accuracy: 0.9741 - loss: 0.0833 - val_accuracy: 0.9478 - val_loss: 0.1717 - lr: 6.25e-06
# Early stopping at epoch 105
# === Validation report (threshold=0.5) ===
#               precision    recall  f1-score   support
#
#          0.0     0.9590    0.9698    0.9644      2052
#          1.0     0.9161    0.8885    0.9021       762
#
#     accuracy                         0.9478      2814
#    macro avg     0.9376    0.9291    0.9332      2814
# weighted avg     0.9474    0.9478    0.9475      2814
#
# Validation ROC AUC: 0.9761
# === Test report (threshold=0.5) ===
#               precision    recall  f1-score   support
#
#          0.0     0.9501    0.9690    0.9595      1710
#          1.0     0.9118    0.8630    0.8867       635
#
#     accuracy                         0.9403      2345
#    macro avg     0.9310    0.9160    0.9231      2345
# weighted avg     0.9397    0.9403    0.9398      2345
#
# Test ROC AUC: 0.9656

# %%
# 3. Save model and splits
model_path = os.path.join(PROCESSED_DIR, "seizure_cnn_model.pth")
torch.save(model.state_dict(), model_path)

print(f"Model weights saved to: {model_path}")
# Out:
# Model weights saved to: /kaggle/working/processed_chb_mit/seizure_cnn_model.pth

# %% [markdown]
# # Stage 3 — SNN conversion & inference

# %%
baseline = EEGCNN(in_channels=len(CHANNELS))
baseline.load_state_dict(torch.load(model_path, map_location=DEVICE))
baseline.to(DEVICE)
baseline.eval()

snn_model = copy.deepcopy(baseline)
snn_model.eval()

def max_activation(model, X_sample, DEVICE):
    act = {}
    def hook_output(name):
        def hook(model, input, output):
            output = output.detach().abs()
            val = torch.quantile(output.detach().abs(), 0.999).item()
            act[name] = max(1e-5,val)
        return hook

    hooks = []
    
    for name, m in model.named_modules():
        if isinstance(m, (nn.Conv1d, nn.Linear)):
            hooks.append(m.register_forward_hook(hook_output(name)))
    try:
        X_tensor = torch.tensor(X_sample).float().to(DEVICE)
        input_max = torch.quantile(X_tensor.abs(), 0.999).item()
        with torch.no_grad():
            model(X_tensor)
    finally:
        for h in hooks: 
            h.remove()
    return act, input_max

max_activations, input_max = max_activation(baseline, X_test[:200], DEVICE)

layer_names = ['conv1', 'conv2', 'conv3', 'conv4', 'conv5', 'conv6', 'fc1', 'fc2', 'fc3']
prev_max = input_max

with torch.no_grad():
    for name in layer_names:
        layer = dict(snn_model.named_modules())[name]
        curr_max = max_activations[name]
 
        layer.weight.data *= prev_max / curr_max
        if layer.bias is not None:
            layer.bias.data *= 1.0 / curr_max
        prev_max = curr_max

class IFNeuron(nn.Module):
    def __init__(self, th=1.0):
        super().__init__()
        self.th = th
    
    def forward(self, x, mem):
        mem += x
        spike = (mem >= self.th).float()
        mem = mem - spike * self.th # Soft reset
        return spike, mem

class SNN_Norm(nn.Module):
    def __init__(self, normalized_model):
        super().__init__()
        self.conv1 = normalized_model.conv1
        self.conv2 = normalized_model.conv2
        self.pool1 = normalized_model.pool1
        self.conv3 = normalized_model.conv3
        self.conv4 = normalized_model.conv4
        self.pool2 = normalized_model.pool2
        self.conv5 = normalized_model.conv5
        self.conv6 = normalized_model.conv6
        self.pool3 = normalized_model.pool3
        self.global_pool = normalized_model.global_pool
        self.fc1 = normalized_model.fc1
        self.fc2 = normalized_model.fc2
        self.fc3 = normalized_model.fc3

        self.neurons = nn.ModuleDict({name: IFNeuron(th=1.0) for name in ['conv1','conv2','conv3','conv4','conv5','conv6','fc1','fc2']})
        
    def forward(self, x_analog, time_steps):
        mem = {k: 0.0 for k in self.neurons.keys()}
        mem_out = 0.0
        outputs = []
        
        for t in range(time_steps):
            x = x_analog 
            x = self.conv1(x)
            x, mem['conv1'] = self.neurons['conv1'](x, mem['conv1'])
            x = self.conv2(x)
            x, mem['conv2'] = self.neurons['conv2'](x, mem['conv2'])
            x = self.pool1(x)
            
            x = self.conv3(x)
            x, mem['conv3'] = self.neurons['conv3'](x, mem['conv3'])
            x = self.conv4(x)
            x, mem['conv4'] = self.neurons['conv4'](x, mem['conv4'])
            x = self.pool2(x)
            
            x = self.conv5(x)
            x, mem['conv5'] = self.neurons['conv5'](x, mem['conv5'])
            x = self.conv6(x)
            x, mem['conv6'] = self.neurons['conv6'](x, mem['conv6'])
            x = self.pool3(x)
            
            x = self.global_pool(x).squeeze(-1)
            x = self.fc1(x)
            x, mem['fc1'] = self.neurons['fc1'](x, mem['fc1'])
            x = self.fc2(x)
            x, mem['fc2'] = self.neurons['fc2'](x, mem['fc2'])
                
            mem_out += self.fc3(x) 
            outputs.append(mem_out)
        return torch.stack(outputs)


snn = SNN_Norm(snn_model).to(DEVICE)


def inference(model, X_test, time_steps=50, batch_size=32):
    model.eval()
    logits = []
    
    X_scaled = X_test / input_max
    
    print(f"Inference: {len(X_test)} samples, {time_steps} steps")
    
    with torch.no_grad():
        for i in range(0, len(X_test), batch_size):
            batch = torch.tensor(X_scaled[i:i+batch_size]).float().to(DEVICE)
            voltage = model(batch, time_steps)
            
            # Recover logits
            final_logits = (voltage[-1].squeeze(-1) / time_steps) * max_activations['fc3']
            logits.extend(final_logits.cpu().numpy())
            
    logits_ = np.array(logits)
    probs = expit(logits_)
    return probs

probs = inference(snn, X_test, time_steps=50)

b_acc, b_th, thresholds = 0.0, 0.5, np.arange(0.1, 0.95, 0.05)

for th in thresholds:
    preds_adj = (probs > th).astype(int)
    acc = accuracy_score(y_test, preds_adj)
    
    if acc > b_acc:
        b_acc = acc
        b_th = th

print(f"\nBest Threshold: {b_th:.2f}")
print(f"Best Accuracy:  {b_acc:.4f}")

final_preds = (probs > b_th).astype(int)
print("\n=== SNN RESULTS ===")
print(classification_report(y_test, final_preds, digits=4))
print(f"ROC AUC: {roc_auc_score(y_test, probs):.4f}")
# Out:
# Inference: 2345 samples, 50 steps
#
# Searching for optimal threshold...
#
# Best Threshold: 0.90
# Best Accuracy:  0.8567
#
# === SNN RESULTS ===
#               precision    recall  f1-score   support
#
#        False     0.8962    0.9088    0.9024      1710
#         True     0.7447    0.7165    0.7303       635
#
#     accuracy                         0.8567      2345
#    macro avg     0.8204    0.8127    0.8164      2345
# weighted avg     0.8552    0.8567    0.8558      2345
#
# ROC AUC: 0.8888
